# %% [markdown]
# <a href="https://colab.research.google.com/github/Andavarapu-Snehal-05/Deep-Learning-/blob/main/MiniBatch_Gradient_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as пр
def sigmoid cx)
return 1/(1+ np-exp(-x))
def sigmoid-derivative (x)%.
طور
return x*(1-x)
x= np.array ([[0,0], [0,1], [1,0]、[1、1ココ)
4= np.array ([[0], [0], [0], [])
random-seed co)
weights = np.random.rand(211)
bias = np.random.rand (1.1)
learning-rate = 01
epochs=1000
batch-size=2
for-in range (epochs):
indices = np-random permutation (len(x))
X-shuffled = x (indices]
y-Shuffled = y Cindices]
for i in range co,len(x), batch-sizes:
X-batch=X-shuffled [i'it batch-size]
y-batch = 4-shuffled [i:it batch-size]
z = np. dot(x-batch, weight) + bias
4-pred = sigmoid (2)
ernory-batch - y-pred

d-pred = error * sigmoid-derivative (y-pred d-weights = np.dot (x-batch. T, d-pred) d-bias = np.som (d-pred,axisco, keepdienstig weights += learning-rate * d-weights

bi'as += learning-rate *d-bias

print("Predicted output")

print(sigmoid (np.dot(x, weights) + bias))
# Out:
#   File "/tmp/ipykernel_744/986110303.py", line 2
#     def sigmoid cx)
#                   ^
# SyntaxError: unmatched ')'

# %%
import numpy as np

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def sigmoid_derivative(x_pred):
    return x_pred * (1 - x_pred)

x = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y = np.array([[0], [0], [0], [0]])

np.random.seed(0)

weights = np.random.rand(2, 1) # Adjusted for input shape
bias = np.random.rand(1, 1)
learning_rate = 0.1
epochs = 1000
batch_size = 2

for epoch in range(epochs):
    indices = np.random.permutation(len(x))
    X_shuffled = x[indices]
    y_shuffled = y[indices]

    for i in range(0, len(x), batch_size):
        X_batch = X_shuffled[i : i + batch_size]
        y_batch = y_shuffled[i : i + batch_size]

        z = np.dot(X_batch, weights) + bias
        y_pred = sigmoid(z)

        error = y_batch - y_pred

        d_pred = error * sigmoid_derivative(y_pred)
        d_weights = np.dot(X_batch.T, d_pred)
        d_bias = np.sum(d_pred, axis=0, keepdims=True)

        weights += learning_rate * d_weights
        bias += learning_rate * d_bias

print("Predicted output")
print(sigmoid(np.dot(x, weights) + bias))
# Out:
# Predicted output
# [[0.05803911]
#  [0.03019615]
#  [0.02811745]
#  [0.01440916]]
